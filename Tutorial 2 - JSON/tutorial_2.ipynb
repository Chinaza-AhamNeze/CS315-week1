# %% [markdown]
# # Tutorial 2: Working with JSON data in Python
#
# This tutorial can be found in this link [Working with JSON data in Python](https://realpython.com/python-json/).
#
# **Note:** Use Markdown headings to create sections in the notebook. Run each snippet of code in one cell.

# %% [markdown]
# ## 1. Writing JSON with Python

# %% [markdown]
# ### Convert Python Dictionaries to JSON

# %%
 import json
food_ratings = {"organic dog food": 2, "human food": 10}
json.dumps(food_ratings) #.dumps() convert dictonary to string
'{"organic dog food": 2, "human food": 10}'
# Out:
# '{"organic dog food": 2, "human food": 10}'

# %%
str(food_ratings)
# Out:
# "{'organic dog food': 2, 'human food': 10}"

# %%
numbers_present = {1: True, 2: True, 3: False}
>>> json.dumps(numbers_present)
# Out:
# '{"1": true, "2": true, "3": false}'

# %%
dog_id = 1
>>> dog_name = "Frieda"
>>> dog_registry = {dog_id: {"name": dog_name}}
>>> json.dumps(dog_registry)
# Out:
# '{"1": {"name": "Frieda"}}'

# %%
>>> json.dumps(True)

>>> json.dumps(["eating", "sleeping", "barking"])
# Out:
# '["eating", "sleeping", "barking"]'

# %%
>>> available_nums = {(1, 2): True, 3: False}
>>> json.dumps(available_nums)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 available_nums = {(1, 2): True, 3: False}
# ----> 2 json.dumps(available_nums)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/json/__init__.py:231, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     226 # cached encoder
#     227 if (not skipkeys and ensure_ascii and
#     228     check_circular and allow_nan and
#     229     cls is None and indent is None and separators is None and
#     230     default is None and not sort_keys and not kw):
# --> 231     return _default_encoder.encode(obj)
#     232 if cls is None:
#     233     cls = JSONEncoder
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/json/encoder.py:199, in JSONEncoder.encode(self, o)
#     195         return encode_basestring(o)
#     196 # This doesn't pass the iterator directly to ''.join() because the
#     197 # exceptions aren't as detailed.  The list call should be roughly
#     198 # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199 chunks = self.iterencode(o, _one_shot=True)
#     200 if not isinstance(chunks, (list, tuple)):
#     201     chunks = list(chunks)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/json/encoder.py:257, in JSONEncoder.iterencode(self, o, _one_shot)
#     252 else:
#     253     _iterencode = _make_iterencode(
#     254         markers, self.default, _encoder, self.indent, floatstr,
#     255         self.key_separator, self.item_separator, self.sort_keys,
#     256         self.skipkeys, _one_shot)
# --> 257 return _iterencode(o, 0)
#
# TypeError: keys must be str, int, float, bool or None, not tuple

# %%
>>> json.dumps(available_nums, skipkeys=True)
# Out:
# '{"3": false}'

# %%
toy_conditions = {"chew bone": 7, "ball": 3, "sock": -1}
>>> json.dumps(toy_conditions, sort_keys=True)
# Out:
# '{"ball": 3, "chew bone": 7, "sock": -1}'

# %% [markdown]
# ### Write a JSON File With Python

# %%
import json

dog_data = {
  "name": "Frieda",
  "is_dog": True,
  "hobbies": ["eating", "sleeping", "barking",],
  "age": 8,
  "address": {
    "work": None,
    "home": ("Berlin", "Germany",),
  },
  "friends": [
    {
      "name": "Philipp",
      "hobbies": ["eating", "sleeping", "reading",],
    },
    {
      "name": "Mitch",
      "hobbies": ["running", "snacking",],
    },
  ],
}

with open("hello_frieda.json", mode="w", encoding="utf-8") as write_file:
    json.dump(dog_data, write_file)

# %% [markdown]
# ## Reading JSON with Python

# %% [markdown]
# ### Convert JSON Objects to a Python Dictionary

# %%
>>> import json
>>> dog_registry = {1: {"name": "Frieda"}}
>>> dog_json = json.dumps(dog_registry)
>>> dog_json
# Out:
# '{"1": {"name": "Frieda"}}'

# %%
>>> new_dog_registry = json.loads(dog_json)

# %%
>>> new_dog_registry == dog_registry


>>> new_dog_registry


>>> dog_registry
# Out:
# {1: {'name': 'Frieda'}}

# %% [markdown]
# ### Deseralize JSON Data Types

# %%
>>> dog_data = {
...   "name": "Frieda",
...   "is_dog": True,
...   "hobbies": ["eating", "sleeping", "barking",],
...   "age": 8,
...   "address": {
...     "work": None,
...     "home": ("Berlin", "Germany",),
...   },
... }

# %%
>>> dog_data_json = json.dumps(dog_data)
>>> dog_data_json

>>> new_dog_data = json.loads(dog_data_json)
>>> new_dog_data
# Out:
# {'name': 'Frieda',
#  'is_dog': True,
#  'hobbies': ['eating', 'sleeping', 'barking'],
#  'age': 8,
#  'address': {'work': None, 'home': ['Berlin', 'Germany']}}

# %%
type(dog_data["address"]["home"])
type(new_dog_data["address"]["home"])
# Out:
# list

# %%
>>> import json
>>> with open("hello_frieda.json", mode="r", encoding="utf-8") as read_file:
...     frie_data = json.load(read_file)
...
>>> type(frie_data)


>>> frie_data["name"]
# Out:
# 'Frieda'

# %%
>>> from hello_frieda import dog_data
>>> frie_data == dog_data


>>> type(frie_data["address"]["home"])


>>> type(dog_data["address"]["home"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 from hello_frieda import dog_data
#       2 frie_data == dog_data
#       5 type(frie_data["address"]["home"])
#
# ModuleNotFoundError: No module named 'hello_frieda'

# %% [markdown]
# ## Interacting with JSON

# %%
>>> import json
>>> dog_friend = {
...     "name": "Mitch",
...     "age": 6.5,
... }

>>> print(json.dumps(dog_friend))


>>> print(json.dumps(dog_friend, indent=0))


>>> print(json.dumps(dog_friend, indent=-2))

>>> print(json.dumps(dog_friend, indent=""))


>>> print(json.dumps(dog_friend, indent=" ⮑ "))
# Out:
# {"name": "Mitch", "age": 6.5}
# {
# "name": "Mitch",
# "age": 6.5
# }
# {
# "name": "Mitch",
# "age": 6.5
# }
# {
# "name": "Mitch",
# "age": 6.5
# }
# {
#  ⮑ "name": "Mitch",
#  ⮑ "age": 6.5
# }

# %%
>>> print(json.dumps(dog_friend, indent=2))


>>> print(json.dumps(dog_friend, indent=4))
{
    "name": "Mitch",
    "age": 6.5
}
# Out:
# {
#   "name": "Mitch",
#   "age": 6.5
# }
# {
#     "name": "Mitch",
#     "age": 6.5
# }
# {'name': 'Mitch', 'age': 6.5}

# %%
>>> with open("dog_friend.json", mode="w", encoding="utf-8") as write_file:
...     json.dump(dog_friend, write_file, indent=4)
...
