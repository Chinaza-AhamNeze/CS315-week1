# %% [markdown]
# # Tutorial 1: Working with Files in Python
#
# This tutorial can be found in this link [Working with Files in Python](https://realpython.com/working-with-files-in-python/).
#
# **Note:** Use Markdown headings to create sections in the notebook. Run each snippet of code in one cell.

# %% [markdown]
# ## 1. `with ... open as` pattern

# %%
with open('data.txt', 'r') as f:
    data =f.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 with open('data.txt', 'r') as f:
#       2     data =f.read()
#
# File ~/Library/Python/3.9/lib/python/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data.txt'

# %%
with open('data.txt', 'w')as f:
    data = 'some data to be written to the file'
    f.write(data)

# %% [markdown]
# ## 2. Getting a Directory Listing

# %%
import os
entries = os.listdir('/Users/chinazaaham-neze/Desktop/CS315')

# %%
os.listdir('/Users/chinazaaham-neze/Desktop/CS315')
# Out:
# ['cs315personal',
#  'CS315-week3-fri',
#  '.DS_Store',
#  'CS315-Week3-wed',
#  'week-2-lab-CS315',
#  '.venv',
#  '.vscode',
#  'CS315-Week2--task--fri',
#  'CS315-week1']

# %%
entries = os.listdir('/Users/chinazaaham-neze/Desktop/CS315')
for entry in entries:
    print(entry)
# Out:
# cs315personal
# CS315-week3-fri
# .DS_Store
# CS315-Week3-wed
# week-2-lab-CS315
# .venv
# .vscode
# CS315-Week2--task--fri
# CS315-week1

# %%
import os 
entries = os.scandir('/Users/chinazaaham-neze/Desktop/CS315')
entries

# %%
import os 

with os.scandir('/Users/chinazaaham-neze/Desktop/CS315') as entries:
    for entry in entries:
        print(entry.name)
# Out:
# cs315personal
# CS315-week3-fri
# .DS_Store
# CS315-Week3-wed
# week-2-lab-CS315
# .venv
# .vscode
# CS315-Week2--task--fri
# CS315-week1

# %%
from pathlib import Path

entries = Path('/Users/chinazaaham-neze/Desktop/CS315')
for entry in entries.iterdir():
    print(entry.name)
# Out:
# cs315personal
# CS315-week3-fri
# .DS_Store
# CS315-Week3-wed
# week-2-lab-CS315
# .venv
# .vscode
# CS315-Week2--task--fri
# CS315-week1

# %%
import os

#List all file sin a directory using os.listdir
basepath = '/Users/chinazaaham-neze/Desktop/CS315'

for entry in os.listdir(basepath):
    if os.path.isfile(os.path.join(basepath, entry)):
        print(entry)
# Out:
# .DS_Store

# %%
import os

#List all files in a directory using scandir()

basepath= '/Users/chinazaaham-neze/Desktop/CS315'

with os.scandir(basepath) as entries:
    for entry in entries:
        if entry in entries:
            print(entry.name)

# %%
from pathlib import Path 

basepath = Path('/Users/chinazaaham-neze/Desktop/CS315')

files_in_basepath = basepath.iterdir()

for item in files_in_basepath:
    if item.is_file():
        print(item.name)
# Out:
# .DS_Store

# %%
from pathlib import Path 

#List all files in directory using pathlib

basepath = Path('/Users/chinazaaham-neze/Desktop/CS315')

files_in_basepath = (entry for entry in basepath.iterdir() if entry.is_file())
for item in files_in_basepath:
    print(item.name)
# Out:
# .DS_Store

# %%
import os 

#List all subdirectories using os.listdir

basepath ='/Users/chinazaaham-neze/Desktop/CS315'
for entry in os.listdir(basepath):
    if os.path.isdir(os.path.join(basepath, entry)):
        print(entry)
# Out:
# cs315personal
# CS315-week3-fri
# CS315-Week3-wed
# week-2-lab-CS315
# .venv
# .vscode
# CS315-Week2--task--fri
# CS315-week1

# %%
import os 

#List all subdirectories using scandir()

basepath ='/Users/chinazaaham-neze/Desktop/CS315'
with os.scandir(basepath) as entries:
    for entry in entries:
        if entry.is_dir():
            print(entry.name)
# Out:
# cs315personal
# CS315-week3-fri
# CS315-Week3-wed
# week-2-lab-CS315
# .venv
# .vscode
# CS315-Week2--task--fri
# CS315-week1

# %%
from pathlib import Path 

#List all subdirectory using pathlib
basepath= Path('/Users/chinazaaham-neze/Desktop/CS315')
for entry in basepath.iterdir():
    if entry.is_dir():
        print(entry.name)
# Out:
# cs315personal
# CS315-week3-fri
# CS315-Week3-wed
# week-2-lab-CS315
# .venv
# .vscode
# CS315-Week2--task--fri
# CS315-week1

# %%
import os
with os.scandir('/Users/chinazaaham-neze/Desktop/CS315') as dir_contents:
    for entry in dir_contents:
        info= entry.stat()
        print(info.st_mtime)
# Out:
# 1788372756.1639576
# 1789752245.3157551
# 1789998619.0804255
# 1789579097.2735457
# 1789517194.879945
# 1789515304.9328234
# 1788369201.6504824
# 1789146307.4747188
# 1789998583.6763527

# %%
from pathlib import Path 
current_dir = Path('/Users/chinazaaham-neze/Desktop/CS315')
for path in current_dir.iterdir():
    info = path.stat()
    print(info.st_mtime)
# Out:
# 1788372756.1639576
# 1789752245.3157551
# 1789998619.0804255
# 1789579097.2735457
# 1789517194.879945
# 1789515304.9328234
# 1788369201.6504824
# 1789146307.4747188
# 1789998583.6763527

# %%
from datetime import datetime
from os import scandir

def convert_date(timestamp):
    d = datetime.utcfromtimestamp(timestamp)
    formated_date = d.strftime('%d %b %Y')
    return fromated_date

def get_files():
    dir_entries = scandir('/Users/chinazaaham-neze/Desktop/CS315')
    for entry in dir_entries:
        if entry.is_file():
            info = entry.stat()
            print(f'{entry.name}\t  Last Modified: {convert_date(info.st_mtime)}')

# %%
get_files()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 get_files()
#
# Cell In[28], line 14, in get_files()
#      12 if entry.is_file():
#      13     info = entry.stat()
# ---> 14     print(f'{entry.name}\t  Last Modified: {convert_date(info.st_mtime)}')
#
# Cell In[28], line 7, in convert_date(timestamp)
#       5 d = datetime.utcfromtimestamp(timestamp)
#       6 formated_date = d.strftime('%d %b %Y')
# ----> 7 return fromated_date
#
# NameError: name 'fromated_date' is not defined

# %% [markdown]
# ## Making Directories

# %%
import os
os.mkdir('example/')

# %%
from pathlib import Path

p= Path('example/')
p.mkdir()
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[31], line 4
#       1 from pathlib import Path
#       3 p= Path('example/')
# ----> 4 p.mkdir()
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/pathlib.py:1313, in Path.mkdir(self, mode, parents, exist_ok)
#    1309 """
#    1310 Create a new directory at this given path.
#    1311 """
#    1312 try:
# -> 1313     self._accessor.mkdir(self, mode)
#    1314 except FileNotFoundError:
#    1315     if not parents or self.parent == self:
#
# FileExistsError: [Errno 17] File exists: 'example'

# %%
from pathlib import Path

p= Path('/Users/chinazaaham-neze/Desktop/CS315')
try:
    p.mkdir()
except FileExistsError as exc:
    print(exc)
# Out:
# [Errno 17] File exists: '/Users/chinazaaham-neze/Desktop/CS315'

# %% [markdown]
# ## Creating Multiple Directory

# %%
import os

os.makedirs('2018/10/05')

# %%
import os 
os.makedirs('2018/10/05', mode=0o770)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[34], line 2
#       1 import os
# ----> 2 os.makedirs('2018/10/05', mode=0o770)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/os.py:225, in makedirs(name, mode, exist_ok)
#     223         return
#     224 try:
# --> 225     mkdir(name, mode)
#     226 except OSError:
#     227     # Cannot rely on checking for EEXIST, since the operating system
#     228     # could give priority to other errors like EACCES or EROFS
#     229     if not exist_ok or not path.isdir(name):
#
# FileExistsError: [Errno 17] File exists: '2018/10/05'

# %%
import pathlib

p= pathlib.Path('2018/10/05')

p.mkdir(parents=True)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[35], line 5
#       1 import pathlib
#       3 p= pathlib.Path('2018/10/05')
# ----> 5 p.mkdir(parents=True)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/pathlib.py:1313, in Path.mkdir(self, mode, parents, exist_ok)
#    1309 """
#    1310 Create a new directory at this given path.
#    1311 """
#    1312 try:
# -> 1313     self._accessor.mkdir(self, mode)
#    1314 except FileNotFoundError:
#    1315     if not parents or self.parent == self:
#
# FileExistsError: [Errno 17] File exists: '2018/10/05'

# %%
## Filename Pattern Matching 
import os

# Get .txt files
 for f_name in os.listdir('some_directory'):
        if f_name.endswith('.txt'):
                print(f_name)
# Out:
#   Cell In[36], line 5
#     for f_name in os.listdir('some_directory'):
#     ^
# IndentationError: unexpected indent

# %%
import os
import fnmatch

for file_name in os.listdir('some_directory/'):
    if fnmatch(file_name, '*.txt'):
        prinr(file_name)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[37], line 4
#       1 import os
#       2 import fnmatch
# ----> 4 for file_name in os.listdir('some_directory/'):
#       5     if fnmatch(file_name, '*.txt'):
#       6         prinr(file_name)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'some_directory/'

# %%
for filename in os.listdir('.'):
    if fnmatch.fnmatch(filename, 'data_*backup.txt'):
        print(filename)

# %% [markdown]
# ## Filename Pattern Matching Using glob

# %%
import glob
glob.glob('*.py')
# Out:
# []

# %%
import glob
for name in glob.glob('*[0-9]*.txt'):
    print(name)

# %%
import glob
for file in glob.iglob('**/*.py', recursive = True):
    print(file)

# %%
from pathlib import Path
>>> p = Path('.')
>>> for name in p.glob('*.p*'):
...     print(name)

# %% [markdown]
# ## Traversing Directories and Processing Files

# %%
# Walking a directory tree and printing the names of the directories and files
for dirpath, dirnames, files in os.walk('.'):
    print(f'Found directory: {dirpath}')
    for file_name in files:
        print(file_name)
# Out:
# Found directory: .
# tutorial_1.ipynb
# data.txt
# Found directory: ./example
# Found directory: ./2018
# Found directory: ./2018/10
# Found directory: ./2018/10/05

# %%
for dirpath, dirnames, files in os.walk('.', topdown=False):
    print(f'Found directory: {dirpath}')
    for file_name in files:
        print(file_name)
# Out:
# Found directory: ./example
# Found directory: ./2018/10/05
# Found directory: ./2018/10
# Found directory: ./2018
# Found directory: .
# tutorial_1.ipynb
# data.txt

# %% [markdown]
# ## Mkaing Temp Files and Directories

# %%
from tempfile import TemporaryFile

# Create a temporary file and write some data to it
fp = TemporaryFile('w+t')
fp.write('Hello universe!')

# Go back to the beginning and read data from file
fp.seek(0)
data = fp.read()

# Close the file, after which it will be removed
fp.close()

# %%
with TemporaryFile('w+t') as fp:
    fp.write('Hello universe!')
    fp.seek(0)
    fp.read()
# File is now closed and removed

# %%
>>> import tempfile
>>> with tempfile.TemporaryDirectory() as tmpdir:
...     print('Created temporary directory ', tmpdir)
...     os.path.exists(tmpdir)
...

>>> # Directory contents have been removed
...
>>> tmpdir
'/tmp/tmpoxbkrm6c'
>>> os.path.exists(tmpdir)
False
# Out:
# Created temporary directory  /var/folders/g6/ztjpybv97cz7tqp67rkgc5nw0000gn/T/tmpgiuh53q1
# False

# %% [markdown]
# ## Deleting Files and Directories

# %%
import os

data_file = 'C:\\Users\\vuyisile\\Desktop\\Test\\data.txt'
os.remove(data_file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[49], line 4
#       1 import os
#       3 data_file = 'C:\\Users\\vuyisile\\Desktop\\Test\\data.txt'
# ----> 4 os.remove(data_file)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\vuyisile\\Desktop\\Test\\data.txt'

# %%
import os

data_file = 'C:\\Users\\vuyisile\\Desktop\\Test\\data.txt'
os.unlink(data_file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[50], line 4
#       1 import os
#       3 data_file = 'C:\\Users\\vuyisile\\Desktop\\Test\\data.txt'
# ----> 4 os.unlink(data_file)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\vuyisile\\Desktop\\Test\\data.txt'

# %%
import os

data_file = 'home/data.txt'

# If the file exists, delete it
if os.path.isfile(data_file):
    os.remove(data_file)
else:
    print(f'Error: {data_file} not a valid filename')
# Out:
# Error: home/data.txt not a valid filename

# %%
import os

data_file = 'home/data.txt'

# Use exception handling
try:
    os.remove(data_file)
except OSError as e:
    print(f'Error: {data_file} : {e.strerror}')
# Out:
# Error: home/data.txt : No such file or directory

# %%
from pathlib import Path

data_file = Path('home/data.txt')

try:
    data_file.unlink()
except IsADirectoryError as e:
    print(f'Error: {data_file} : {e.strerror}')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[53], line 6
#       3 data_file = Path('home/data.txt')
#       5 try:
# ----> 6     data_file.unlink()
#       7 except IsADirectoryError as e:
#       8     print(f'Error: {data_file} : {e.strerror}')
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/pathlib.py:1344, in Path.unlink(self, missing_ok)
#    1339 """
#    1340 Remove this file or link.
#    1341 If the path is a directory, use rmdir() instead.
#    1342 """
#    1343 try:
# -> 1344     self._accessor.unlink(self)
#    1345 except FileNotFoundError:
#    1346     if not missing_ok:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'home/data.txt'

# %%
import os

trash_dir = 'my_documents/bad_dir'

try:
    os.rmdir(trash_dir)
except OSError as e:
    print(f'Error: {trash_dir} : {e.strerror}')

# %%
from pathlib import Path

trash_dir = Path('my_documents/bad_dir')

try:
    trash_dir.rmdir()
except OSError as e:
    print(f'Error: {trash_dir} : {e.strerror}')

# %% [markdown]
# ## Deleting Entire Directory Trees

# %%
import shutil

trash_dir = 'my_documents/bad_dir'

try:
    shutil.rmtree(trash_dir)
except OSError as e:
    print(f'Error: {trash_dir} : {e.strerror}')

# %%
import os

for dirpath, dirnames, files in os.walk('.', topdown=False):
    try:
        os.rmdir(dirpath)
    except OSError as ex:
        pass

# %%
import shutil

src = 'path/to/file.txt'
dst = 'path/to/dest_dir'
shutil.copy(src, dst)

# %%
import shutil

src = 'path/to/file.txt'
dst = 'path/to/dest_dir'
shutil.copy2(src, dst)

# %% [markdown]
# ## Copying Directories

# %%
>>> import shutil
>>> shutil.copytree('data_1', 'data1_backup')
'data1_backup'

# %% [markdown]
# ## Moving Files and Directories

# %%
>>> import shutil
>>> shutil.move('dir_1/', 'backup/')
'backup'
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/shutil.py:806, in move(src, dst, copy_function)
#     805 try:
# --> 806     os.rename(src, real_dst)
#     807 except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dir_1/' -> 'backup/'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[54], line 2
#       1 import shutil
# ----> 2 shutil.move('dir_1/', 'backup/')
#       3 'backup'
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/shutil.py:826, in move(src, dst, copy_function)
#     824         rmtree(src)
#     825     else:
# --> 826         copy_function(src, real_dst)
# ...

# %% [markdown]
# ## Renaming Files and Directories

# %%
os.rename('first.zip', 'first_01.zip')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 os.rename('first.zip', 'first_01.zip')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'first.zip' -> 'first_01.zip'

# %%
>>> from pathlib import Path
>>> data_file = Path('data_01.txt')
>>> data_file.rename('data.txt')

# %% [markdown]
# ## Reading ZIP Files

# %%
import zipfile

with zipfile.ZipFile('data.zip', 'r') as zipobj:
# Out:
#   Cell In[56], line 3
#     with zipfile.ZipFile('data.zip', 'r') as zipobj:
#                                                     ^
# IndentationError: expected an indented block

# %%
import zipfile

with zipfile.ZipFile('data.zip', 'r') as zipobj:
    zipobj.namelist()

# %%
import zipfile

with zipfile.ZipFile('data.zip', 'r') as zipobj:
    bar_info = zipobj.getinfo('sub_dir/bar.py')
    bar_info.file_size

# %%
>>> bar_info.date_time

>>> bar_info.compress_size

>>> bar_info.filename

# %% [markdown]
# ## Extracting ZIP Archives

# %%
>>> import zipfile
>>> import os

>>> os.listdir('.')


>>> data_zip = zipfile.ZipFile('data.zip', 'r')

>>> # Extract a single file to current directory
>>> data_zip.extract('file1.py')


>>> os.listdir('.')
['file1.py', 'data.zip']

>>> # Extract all files into a different directory
>>> data_zip.extractall(path='extract_dir/')

>>> os.listdir('.')


>>> os.listdir('extract_dir')


>>> data_zip.close()

# %%
>>> import zipfile

>>> with zipfile.ZipFile('secret.zip', 'r') as pwd_zip:
...     # Extract from a password protected archive
...     pwd_zip.extractall(path='extract_dir', pwd='Quish3@o')

# %%
>>> import zipfile

>>> file_list = ['file1.py', 'sub_dir/', 'sub_dir/bar.py', 'sub_dir/foo.py']
>>> with zipfile.ZipFile('new.zip', 'w') as new_zip:
...     for name in file_list:
...         new_zip.write(name)

# %%
>>> # Open a ZipFile object in append mode
>>> with zipfile.ZipFile('new.zip', 'a') as new_zip:
...     new_zip.write('data.txt')
...     new_zip.write('latin.txt')

# %%
import tarfile

with tarfile.open('example.tar', 'r') as tar_file:
    print(tar_file.getnames())

# %%
>>> import tarfile

>>> tar = tarfile.open('example.tar', mode='r')
>>> tar.getnames()
['CONTRIBUTING.rst', 'README.md', 'app.py']

# %%
>>> for entry in tar.getmembers():
...     print(entry.name)
...     print(' Modified:', time.ctime(entry.mtime))
...     print(' Size    :', entry.size, 'bytes')
...     print()

# %%
tar.extract('README.md')
>>> os.listdir('.')

# %%
tar.extractall(path="extracted/")

# %%
>>> f = tar.extractfile('app.py')
>>> f.read()
>>> tar.close()

# %%
>>> import tarfile

>>> file_list = ['app.py', 'config.py', 'CONTRIBUTORS.md', 'tests.py']
>>> with tarfile.open('packages.tar', mode='w') as tar:
...     for file in file_list:
...         tar.add(file)

>>> # Read the contents of the newly created archive
>>> with tarfile.open('package.tar', mode='r') as t:
...     for member in t.getmembers():
...         print(member.name)
app.py
config.py
CONTRIBUTORS.md
tests.py

# %%
>>> with tarfile.open('package.tar', mode='a') as tar:
...     tar.add('foo.bar')

>>> with tarfile.open('package.tar', mode='r') as tar:
...     for member in tar.getmembers():
...         print(member.name)

# %%
>>> files = ['app.py', 'config.py', 'tests.py']
>>> with tarfile.open('packages.tar.gz', mode='w:gz') as tar:
...     tar.add('app.py')
...     tar.add('config.py')
...     tar.add('tests.py')

>>> with tarfile.open('packages.tar.gz', mode='r:gz') as t:
...     for member in t.getmembers():
...         print(member.name)

# %% [markdown]
# ## An Easier Way of Creating Archives

# %%
import shutil

# shutil.make_archive(base_name, format, root_dir)
shutil.make_archive('data/backup', 'tar', 'data/')

# %%
shutil.unpack_archive('backup.tar', 'extract_dir/')

# %% [markdown]
# ## Reading Multiple Files

# %%
import fileinput
for line in fileinput.input()
    process(line)

# %%
# File: fileinput-example.py
import fileinput
import sys

files = fileinput.input()
for line in files:
    if fileinput.isfirstline():
        print(f'\n--- Reading {fileinput.filename()} ---')
    print(' -> ' + line, end='')
print()
